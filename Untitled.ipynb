# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from yahoofinancials import YahooFinancials

# %%
keystats_new = pd.read_csv("keystats_new.csv", index_col="calendardate")
ticker_list = keystats_new.ticker.drop_duplicates().tolist()
ticker_list_a = ticker_list[:10]

# %%
yahoo_financials = YahooFinancials(ticker_list_a)

data = yahoo_financials.get_historical_price_data(start_date = '2010-01-01',
                                                  end_date = '2020-11-11',
                                                  time_interval = 'daily')

# %%
#data frame these stocks
stocks = pd.DataFrame({
      a: {x['formatted_date']: x['adjclose'] for x in data[a]['prices']} for a in ticker_list_a
})
stocks.index.names = ['Date'] # note the data columns are index. cuz in the dictionary: key: value. keys are indexes. 
stocks.round(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-543c582f7e16> in <module>
#       1 #data frame these stocks
# ----> 2 stocks = pd.DataFrame({
#       3       a: {x['formatted_date']: x['adjclose'] for x in data[a]['prices']} for a in ticker_list_a
#       4 })
#       5 stocks.index.names = ['Date'] # note the data columns are index. cuz in the dictionary: key: value. keys are indexes.
#
# <ipython-input-11-543c582f7e16> in <dictcomp>(.0)
#       1 #data frame these stocks
#       2 stocks = pd.DataFrame({
# ----> 3       a: {x['formatted_date']: x['adjclose'] for x in data[a]['prices']} for a in ticker_list_a
#       4 })
#       5 stocks.index.names = ['Date'] # note the data columns are index. cuz in the dictionary: key: value. keys are indexes.
#
# KeyError: 'prices'

# %%
from nbmultitask import ThreadWithLogAndControls

# %%
import builtins
from time import sleep
def print(x):
    builtins.print(2*x)

# the target function will be passed a function called `thread_print`
def fn(thread_print):
    i = 1
    # be careful with loops... (in order for the stop button to work)
    while i <= 5:
        thread_print('%i...' % i)
        sleep(1.5)
        i+=1

task = ThreadWithLogAndControls(target=fn, name="do some stuff")

# %%
task.control_panel()
# Out:
# Button(button_style='success', description='start', style=ButtonStyle())
# Button(button_style='primary', description='watch', style=ButtonStyle())
# Button(description='clear log', style=ButtonStyle())
# Output()

# %%
import multiprocessing

def double(a):
    return a * 2

def driver_func():
    PROCESSES = 4
    with multiprocessing.Pool(PROCESSES) as pool:
        params = [(1, ), (2, ), (3, ), (4, )]
        results = [pool.apply_async(double, p) for p in params]

        for r in results:
            print('\t', r.get())

# %%
driver_func()

# %%
from multiprocessing import Pool

def f(x):
    return x**2

if __name__ == '__main__':-    pool = Pool(4)
    for res in pool.map(f,range(20)):
        print(res)

# %%
df['pandas_SMA_3'] = df.iloc[:,1].rolling(window=3).mean()

# %%
stock_raw_data = pd.read_csv("stock_prices.csv", index_col="Date", parse_dates=True)
# Out:
#                     A         AA   AAI       AAL  AAMC  AAOI      AAON  \
# Date
# 2010-01-04  20.579165  37.018944  0.87  4.496876   NaN   NaN  5.348952
# 2010-01-05  20.355618  35.862801  0.87  5.005957   NaN   NaN  5.193753
# 2010-01-06  20.283297  37.730419  0.87  4.798555   NaN   NaN  4.987716
# 2010-01-07  20.257004  36.930008  0.87  4.939965   NaN   NaN  5.172348
# 2010-01-08  20.250422  37.841591  0.87  4.845690   NaN   NaN  5.233891
#
#                   AAP      AAPL       AAWW  ...      SHLDQ  SIMP  PCOA  HGLD  \
# Date                                        ...
# 2010-01-04  39.094307  6.539882  38.200001  ...  62.962120   NaN   NaN   NaN
# 2010-03-25  41.707180  6.926144  51.970001  ...  82.487778   NaN   NaN   NaN
# 2010-03-26  41.183678  7.056019  52.869999  ...  82.276443   NaN   NaN   NaN
# 2010-03-29  40.902527  7.101552  52.730000  ...  82.827415   NaN   NaN   NaN
# 2010-03-30  40.941288  7.207284  53.230000  ...  82.510422   NaN   NaN   NaN
# 2010-03-31  40.640751  7.181309  53.049999  ...  81.838684   NaN   NaN   NaN
# 2010-04-01  41.067341  7.210952  53.279999  ...  82.080208   NaN   NaN   NaN
# 2010-04-05  41.367870  7.287958  52.610001  ...  81.853775   NaN   NaN   NaN
# 2010-04-06  41.261223  7.320046  51.810001  ...  81.446205   NaN   NaN   NaN
# 2010-04-07  40.815266  7.352440  51.770000  ...  80.087639   NaN   NaN   NaN
# 2010-04-08  40.960678  7.332576  52.790001  ...  80.004616   NaN   NaN   NaN
# 2010-04-09  40.844345  7.388804  54.299999  ...  80.782021   NaN   NaN   NaN
# 2010-04-12  41.115803  7.404083  55.939999  ...  80.049896   NaN   NaN   NaN
# 2010-04-13  40.970383  7.408362  57.590000  ...  80.321609   NaN   NaN   NaN
# 2010-04-14  43.898220  7.507982  58.240002  ...  83.016106   NaN   NaN   NaN
#
#                   EDU  TAL       ZTNO  ZG  UXIN  APLS
# Date
# 2010-03-17  20.600466  NaN  68.500000 NaN   NaN   NaN
# 2010-03-18  19.930185  NaN  68.599998 NaN   NaN   NaN
# 2010-03-19  19.948938  NaN  72.000000 NaN   NaN   NaN
# 2010-03-22  20.366104  NaN  75.598999 NaN   NaN   NaN
# 2010-03-23  20.612181  NaN  72.500000 NaN   NaN   NaN
# 2010-03-24  20.101271  NaN  80.099998 NaN   NaN   NaN
# 2010-03-25  20.077835  NaN  77.099998 NaN   NaN   NaN
# 2010-03-26  19.923157  NaN  75.900002 NaN   NaN   NaN
# 2010-03-29  20.323917  NaN  78.000000 NaN   NaN   NaN
# 2010-03-30  20.309856  NaN  81.599998 NaN   NaN   NaN
# 2010-03-31  20.040339  NaN  74.401001 NaN   NaN   NaN
# 2010-04-01  20.138771  NaN  73.000000 NaN   NaN   NaN
# 2010-04-05  20.703583  NaN  72.500000 NaN   NaN   NaN
# 2010-04-06  21.055126  NaN  73.500000 NaN   NaN   NaN
# 2010-04-07  20.635620  NaN  73.099998 NaN   NaN   NaN
# 2010-04-08  20.581717  NaN  72.699997 NaN   NaN   NaN
# 2010-04-09  20.717648  NaN  72.500000 NaN   NaN   NaN
# 2010-04-12  20.712959  NaN  72.199997 NaN   NaN   NaN
# 2010-04-13  21.097311  NaN  72.000000 NaN   NaN   NaN
# 2010-04-14  21.842585  NaN  73.199997 NaN   NaN   NaN
#
# [20 rows x 4071 columns]

# %%
stock_raw_data_avg = stock_raw_data.iloc[:,].rolling(window=60).mean()

# %%
stock_raw_data_avg.to_csv("stock_prices_avg.csv")

# %%
from datetime import datetime
import backtrader as bt
# %matplotlib inline

class SmaCross(bt.SignalStrategy):
    def __init__(self):
        sma1, sma2 = bt.ind.SMA(period=10), bt.ind.SMA(period=30)
        crossover = bt.ind.CrossOver(sma1, sma2)
        self.signal_add(bt.SIGNAL_LONG, crossover)

cerebro = bt.Cerebro()
cerebro.addstrategy(SmaCross)

data0 = bt.feeds.YahooFinanceData(dataname='MSFT', fromdate=datetime(2011, 1, 1),
                                  todate=datetime(2012, 12, 31))
cerebro.adddata(data0)

cerebro.run()
cerebro.plot()
# Out:
# <div id='0b3d169b-7b96-4528-a7f3-d556e4b101cb'></div>
# [[<Figure size 432x288 with 5 Axes>]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()
